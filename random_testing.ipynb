# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import butter, lfilter

# %%
y_train, y_test = np.load('y_train.npy'), np.load('y_test.npy')

# %%
y_train.shape

# %%
y_train[:,0]

# %%
X = np.load('processed_data/loc9/X.npy')

# %%
y = np.load('processed_data/loc9/y.npy')

# %%
a = np.argwhere(np.isnan(X))
print(a)
print(a.shape)
# Out:
# []
# (0, 3)

# %%
X_train, X_test = np.load('X_train.npy'), np.load('X_test.npy')

# %%
print(X_train.shape)
# Out:
# (1944, 200, 90)

# %%
sample = X_train[0]
plt.plot(sample)
plt.show()

# %%
FS = 1000
def butter_lowpass(cutoff, fs=FS, order=5):
    nyq = 0.5 * fs
    normal_cutoff = cutoff / nyq
    b, a = butter(order, normal_cutoff, btype='low', analog=False)
    return b, a

def butter_lowpass_filter(data, cutoff, fs=FS, order=5):
    b, a = butter_lowpass(cutoff, fs, order=order)
    y = lfilter(b, a, data)
    return y

# %%
a = butter_lowpass_filter(sample[:,0], cutoff=10)

# %%
plt.plot(sample[1000:3000,0])
plt.plot(a[1000:3000])

plt.show()

# %%
sample[0].shape
# Out:
# (90,)

# %%
outliers = np.argwhere(X_test > 40)
outliers
# Out:
# array([], shape=(0, 3), dtype=int64)

# %%
print(X_train[398])
# Out:
# [[9.75162964e+000 9.66095087e+000 9.46792203e+000 ... 9.42712182e+000
#   9.75009072e+000 9.45106615e+000]
#  [9.79954574e+000 9.84207940e+000 9.51192852e+000 ... 9.55174199e+000
#   9.78077029e+000 9.45499180e+000]
#  [9.96642478e+000 1.02017611e+001 9.76201903e+000 ... 9.94936311e+000
#   1.00199475e+001 9.68463331e+000]
#  ...
#  [9.61060730e+000 9.33150336e+000 9.42593629e+000 ... 9.80233333e+000
#   3.30528981e+243 9.32393994e+000]
#  [9.48991610e+000 9.41775302e+000 9.45703534e+000 ... 9.76852992e+000
#   2.62391005e+243 9.31670175e+000]
#  [9.37903620e+000 9.55686051e+000 9.60863308e+000 ... 9.69056220e+000
#   1.33089484e+243 9.34624580e+000]]

# %%
print(X_train[0,0])
# Out:
# [22.56870901 25.19853702 25.88006788 26.56363521 27.4130894  27.45285443
#  27.05606227 26.68814442 26.6330204  26.3968288  25.53780546 25.09263698
#  24.99319332 24.78843308 25.06964133 25.35773226 25.23406424 25.21462244
#  25.11071489 25.00080147 24.65379517 23.69575955 23.32812612 22.72077048
#  22.78111537 22.9576437  23.07963106 23.23663236 22.65387558 21.68984348
#  25.53174972 27.21438237 26.87137688 26.55347775 26.60616141 26.08264103
#  25.48384709 25.25364359 25.42744928 25.48677623 24.75780931 24.30731004
#  23.79619974 22.94564328 22.76110006 21.69105653 19.80411654 18.02129768
#  16.66531791 16.8414913  18.11092613 19.06694469 20.75110079 21.79206033
#  23.12907502 24.03543909 24.39709493 24.58809474 23.84029576 22.86837424
#  20.91282895 23.19061801 23.39475342 23.49685023 23.95744163 23.54970694
#  22.75134604 21.70658874 20.79178331 19.67033713 17.61271872 15.98398978
#  15.00967985 15.07927953 15.69105487 17.16414868 17.99262558 18.92570045
# ...

# %%
sample = X_train[0]

# %%
sample = (wsample)
# Out:
# 28.075698369307634
